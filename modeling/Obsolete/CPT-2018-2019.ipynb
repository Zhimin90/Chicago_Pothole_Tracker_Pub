# %%
import pandas as pd

df = pd.read_csv("Potholes_Patched.csv")

# %%
df.head()
# Out:
#                ADDRESS            REQUEST_DATE         COMPLETION_DATE  \
# 0    2020 N RACINE AVE  09/18/2018 07:10:56 AM  12/12/2018 01:06:43 PM
# 1       4900 W 64TH ST  10/10/2018 01:37:18 PM  12/03/2018 12:45:10 PM
# 2  5345 N MULLIGAN AVE  08/16/2018 01:18:37 PM  09/20/2018 01:51:09 PM
# 3     1431 W DEVON AVE  06/24/2018 11:31:08 AM  08/02/2018 02:41:16 PM
# 4     5429 N MOODY AVE  09/01/2018 12:22:16 AM  09/28/2018 02:34:21 PM
#
#    NUMBER_OF_POTHOLES_FILLED_ON_BLOCK  LATITUDE  LONGITUDE LOCATION
# 0                                   8       NaN        NaN      NaN
# 1                                   8       NaN        NaN      NaN
# 2                                  52       NaN        NaN      NaN
# 3                                   1       NaN        NaN      NaN
# 4                                   8       NaN        NaN      NaN

# %%
df['REQUEST_DATE'] = pd.to_datetime(df['REQUEST_DATE'])

# %%
df['COMPLETION_DATE'] = pd.to_datetime(df['COMPLETION_DATE'])

# %%
df.sort_values(['REQUEST_DATE','COMPLETION_DATE'], ascending=[0,0])
# Out:
#                              ADDRESS        REQUEST_DATE     COMPLETION_DATE  \
# 44507            3848 W LAWRENCE AVE 2019-12-19 14:48:08 2019-12-19 14:49:36
# 44497                  812 E 48TH ST 2019-12-19 14:24:02 2019-12-19 14:25:44
# 44326            11200 S WESTERN AVE 2019-12-19 13:54:19 2019-12-19 13:56:17
# 44485                 1306 E 56TH ST 2019-12-19 11:29:41 2019-12-19 11:31:56
# 44514                 1201 E 56TH ST 2019-12-19 11:27:22 2019-12-19 11:28:43
# ...                              ...                 ...                 ...
# 31472           7946 S KEDZIE Avenue 2018-03-08 15:29:10 2019-02-07 11:41:59
# 19013               2300 W NORTH AVE 2018-02-25 10:43:49 2018-07-02 08:44:33
# 13422  2413 N SB OUTER LAKE SHORE DR 2018-02-22 19:37:49 2018-08-16 07:27:14
# 31368            330 W GOETHE Street 2018-01-31 13:11:12 2018-12-26 12:40:18
# 10243             5214 N LOVEJOY AVE 2018-01-19 20:58:00 2018-11-08 10:48:35
#
# ...

# %%
df.sort_values(['REQUEST_DATE','COMPLETION_DATE'], ascending=[1,1])
# Out:
#                              ADDRESS        REQUEST_DATE     COMPLETION_DATE  \
# 10243             5214 N LOVEJOY AVE 2018-01-19 20:58:00 2018-11-08 10:48:35
# 31368            330 W GOETHE Street 2018-01-31 13:11:12 2018-12-26 12:40:18
# 13422  2413 N SB OUTER LAKE SHORE DR 2018-02-22 19:37:49 2018-08-16 07:27:14
# 19013               2300 W NORTH AVE 2018-02-25 10:43:49 2018-07-02 08:44:33
# 31472           7946 S KEDZIE Avenue 2018-03-08 15:29:10 2019-02-07 11:41:59
# ...                              ...                 ...                 ...
# 44514                 1201 E 56TH ST 2019-12-19 11:27:22 2019-12-19 11:28:43
# 44485                 1306 E 56TH ST 2019-12-19 11:29:41 2019-12-19 11:31:56
# 44326            11200 S WESTERN AVE 2019-12-19 13:54:19 2019-12-19 13:56:17
# 44497                  812 E 48TH ST 2019-12-19 14:24:02 2019-12-19 14:25:44
# 44507            3848 W LAWRENCE AVE 2019-12-19 14:48:08 2019-12-19 14:49:36
#
# ...
